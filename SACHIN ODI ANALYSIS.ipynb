# %%
import pandas as pd # For data analytics

# %%
sachin = pd.read_csv('tendulkar_ODI.csv')
sachin
# Reading the csv file in to jupiter note book using pd.read_csv
# Out:
#      Unnamed: 0 Runs Mins   BF  4s 6s      SR Pos Dismissal Inns  \
# 0             1    0    -    2   0  0       0   5    caught    2
# 1             2    0    2    2   0  0       0   5    caught    2
# 2             3   36   51   39   5  0    92.3   6    caught    1
# 3             4   19   38   35   1  1   54.28   4    bowled    2
# 4             5   31   31   26   3  0  119.23   6    bowled    2
# ..          ...  ...  ...  ...  .. ..     ...  ..       ...  ...
# 290         291   18   21   14   2  0  128.57   2    caught    2
# 291         292    2    9    6   0  0   33.33   2    caught    2
# 292         293    3   21   12   0  0      25   2    caught    2
# 293         294   14   34   15   2  0   93.33   2   run out    2
# 294         295  114  205  147  12  1   77.55   2    caught    1
#
#         Opposition      Ground Start Date
# 0       v Pakistan  Gujranwala  18-Dec-89
# 1    v New Zealand     Dunedin   1-Mar-90
# 2    v New Zealand  Wellington   6-Mar-90
# ...

# %%
sachin = sachin.rename(columns={'Unnamed: 0':'Innings Number'})
sachin = sachin.rename(columns={'Start Date':'Year'})
sachin = sachin.rename(columns={'BF':'Balls Faced'})
# Renaming the columns

# %%
sachin
# Out:
#      Innings Number Runs Mins Balls Faced  4s 6s      SR Pos Dismissal Inns  \
# 0                 1    0    -           2   0  0       0   5    caught    2
# 1                 2    0    2           2   0  0       0   5    caught    2
# 2                 3   36   51          39   5  0    92.3   6    caught    1
# 3                 4   19   38          35   1  1   54.28   4    bowled    2
# 4                 5   31   31          26   3  0  119.23   6    bowled    2
# ..              ...  ...  ...         ...  .. ..     ...  ..       ...  ...
# 290             291   18   21          14   2  0  128.57   2    caught    2
# 291             292    2    9           6   0  0   33.33   2    caught    2
# 292             293    3   21          12   0  0      25   2    caught    2
# 293             294   14   34          15   2  0   93.33   2   run out    2
# 294             295  114  205         147  12  1   77.55   2    caught    1
#
#         Opposition      Ground       Year
# ...

# %%
sachin['Year']=sachin['Year'].apply(lambda x: x.split('-'))
# apply(lambda x: ...) applies the lambda function to each value in the column
# x.split('-') splits each string on '-' into a list

# %%
sachin['Year']
# Out:
# 0      [18, Dec, 89]
# 1       [1, Mar, 90]
# 2       [6, Mar, 90]
# 3      [18, Jul, 90]
# 4      [20, Jul, 90]
#            ...
# 290     [2, Apr, 11]
# 291     [5, Feb, 12]
# 292    [19, Feb, 12]
# 293    [26, Feb, 12]
# 294    [16, Mar, 12]
# Name: Year, Length: 295, dtype: object

# %%
sachin['Year']=sachin['Year'].apply(lambda x: x[2].split(',')[0])
# x[2] - accesses index 2 of the list, which contains the year string '1989'
# .split(',')[0] - splits on ',' and takes the first part, to remove any trailing comma after year

# %%
sachin['Year']
# Out:
# 0      89
# 1      90
# 2      90
# 3      90
# 4      90
#        ..
# 290    11
# 291    12
# 292    12
# 293    12
# 294    12
# Name: Year, Length: 295, dtype: object

# %%
sachin
# Out:
#      Innings Number Runs Mins Balls Faced  4s 6s      SR Pos Dismissal Inns  \
# 0                 1    0    -           2   0  0       0   5    caught    2
# 1                 2    0    2           2   0  0       0   5    caught    2
# 2                 3   36   51          39   5  0    92.3   6    caught    1
# 3                 4   19   38          35   1  1   54.28   4    bowled    2
# 4                 5   31   31          26   3  0  119.23   6    bowled    2
# ..              ...  ...  ...         ...  .. ..     ...  ..       ...  ...
# 290             291   18   21          14   2  0  128.57   2    caught    2
# 291             292    2    9           6   0  0   33.33   2    caught    2
# 292             293    3   21          12   0  0      25   2    caught    2
# 293             294   14   34          15   2  0   93.33   2   run out    2
# 294             295  114  205         147  12  1   77.55   2    caught    1
#
#         Opposition      Ground Year
# ...

# %%
sachin.isnull().sum()
# checking if there are any null values
# Out:
# Innings Number    0
# Runs              0
# Mins              0
# Balls Faced       0
# 4s                0
# 6s                0
# SR                0
# Pos               0
# Dismissal         0
# Inns              0
# Opposition        0
# Ground            0
# Year              0
# dtype: int64

# %%
sachin.info()
# provides a summary of the DataFrame 'sachin', including the data types of each column and the number of non-null entries.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Innings Number  295 non-null    int64
#  1   Runs            295 non-null    object
#  2   Mins            295 non-null    object
#  3   Balls Faced     295 non-null    object
#  4   4s              295 non-null    object
#  5   6s              295 non-null    object
#  6   SR              295 non-null    object
#  7   Pos             295 non-null    object
#  8   Dismissal       295 non-null    object
#  9   Inns            295 non-null    object
#  10  Opposition      295 non-null    object
#  11  Ground          295 non-null    object
#  12  Year            295 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 30.1+ KB

# %%
sachin['Runs'].unique()
# Out:
# array(['0', '36', '19', '31', '53', '30', 'DNB', '4', '62', '1', '57',
#        '21', '69', '11', '84', '39', '15', '10', '22', '32', '23', '82*',
#        '3', '24', '5', '34', '8*', '25', '26*', '2', '28*', '11*', '52',
#        '82', '63', '40', '6', '8', '115', '66', '54', '88', '105', '13',
#        '7', '65', '127*', '70', '90', '137', '110', '64', '28', '67',
#        '114', '14', '45', '44', '65*', '9', '117', '27', '100', '33',
#        '18', '100*', '17', '128', '29', '37', '120', '186*', '12', '26',
#        '122', '93', '146', '35', '139', '70*', '101', '38', '68', '87*',
#        '34*', '81', '89', '102', '86', '141', '74', '16', '47', '123',
#        '67*', '42', '95', '55', '60', 'TDNB', '99', '71', '94', '43',
#        '79', '72', '97', '117*', '91', '50', '20', '163*', '138', '175',
#        '96*', '200*', '111', '85'], dtype=object)

# %%
sachin=sachin.drop(sachin[sachin['Runs'].isin(['TDNB','DNB'])].index)
# removing TDNB AND DNB rows from Runs column using drop

# %%
sachin['Runs'].unique()
# Out:
# array(['0', '36', '19', '31', '53', '30', '4', '62', '1', '57', '21',
#        '69', '11', '84', '39', '15', '10', '22', '32', '23', '82*', '3',
#        '24', '5', '34', '8*', '25', '26*', '2', '28*', '11*', '52', '82',
#        '63', '40', '6', '8', '115', '66', '54', '88', '105', '13', '7',
#        '65', '127*', '70', '90', '137', '110', '64', '28', '67', '114',
#        '14', '45', '44', '65*', '9', '117', '27', '100', '33', '18',
#        '100*', '17', '128', '29', '37', '120', '186*', '12', '26', '122',
#        '93', '146', '35', '139', '70*', '101', '38', '68', '87*', '34*',
#        '81', '89', '102', '86', '141', '74', '16', '47', '123', '67*',
#        '42', '95', '55', '60', '99', '71', '94', '43', '79', '72', '97',
#        '117*', '91', '50', '20', '163*', '138', '175', '96*', '200*',
#        '111', '85'], dtype=object)

# %%
sachin['Runs']=sachin['Runs'].astype('str')
# Using .astype('str') to convert Runs column into string data type

# %%
sachin
# Out:
#      Innings Number Runs Mins Balls Faced  4s 6s      SR Pos Dismissal Inns  \
# 0                 1    0    -           2   0  0       0   5    caught    2
# 1                 2    0    2           2   0  0       0   5    caught    2
# 2                 3   36   51          39   5  0    92.3   6    caught    1
# 3                 4   19   38          35   1  1   54.28   4    bowled    2
# 4                 5   31   31          26   3  0  119.23   6    bowled    2
# ..              ...  ...  ...         ...  .. ..     ...  ..       ...  ...
# 290             291   18   21          14   2  0  128.57   2    caught    2
# 291             292    2    9           6   0  0   33.33   2    caught    2
# 292             293    3   21          12   0  0      25   2    caught    2
# 293             294   14   34          15   2  0   93.33   2   run out    2
# 294             295  114  205         147  12  1   77.55   2    caught    1
#
#         Opposition      Ground Year
# ...

# %%
sachin['Runs']=sachin['Runs'].apply(lambda x: x.split('*')[0])
# Appling a lambda function to the 'Runs' column, which splits each entry using the '*' delimiter and takes the first element [0].

# %%
sachin['Runs']=sachin['Runs'].astype('int64')

# %%
sachin['Mins'].unique()
# Out:
# array(['-', '2', '51', '38', '31', '79', '111', '64', '12', '116', '19',
#        '122', '92', '9', '7', '42', '16', '8', '10', '25', '83', '22',
#        '69', '91', '34', '125', '13', '6', '3', '28', '184', '53', '80',
#        '101', '130', '147', '180', '30', '27', '96', '14', '175', '137',
#        '124', '198', '103', '26', '18', '20', '189', '133', '55', '128',
#        '157', '48', '57', '17', '188', '49', '109', '4', '41', '24',
#        '110', '23', '104', '21', '44', '132', '45', '33', '156', '182',
#        '155', '37', '105', '191', '61', '221', '66', '39', '195', '119',
#        '90', '200', '113', '47', '35', '197', '68', '129', '209', '82',
#        '71', '120', '60', '158', '29', '117', '173', '170', '46', '15',
#        '192', '149', '87', '76', '77', '81', '134', '54', '112', '94',
#        '52', '43', '123', '235', '176', '40', '99', '11', '206', '63',
#        '214', '86', '210', '187', '226', '78', '93', '160', '205'],
#       dtype=object)

# %%
sachin=sachin.drop(sachin[sachin['Mins'].isin(['-'])].index)
sachin['Mins']=sachin['Mins'].astype('int64')
# Droping rows from the 'sachin' where the 'Mins' column contains '-'.

# %%
sachin['4s'].unique()
# Out:
# array(['0', '5', '1', '3', '6', '7', '2', '15', '9', '8', '13', '10', '4',
#        '14', '11', '20', '12', '19', '17', '16', '25'], dtype=object)

# %%
sachin['6s'].unique()
# Out:
# array(['0', '1', '2', '3', '5', '7', '4'], dtype=object)

# %%
sachin['Pos'].unique()
# Out:
# array(['5', '6', '4', '2', '3', '1'], dtype=object)

# %%
sachin['Inns'].unique()
# Out:
# array(['2', '1'], dtype=object)

# %%
sachin['Year'].unique()
# Out:
# array(['90', '91', '92', '93', '94', '95', '96', '97', '98', '99', '00',
#        '01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11',
#        '12'], dtype=object)

# %%
sachin['SR'].unique()
# Out:
# array(['0', '92.3', '54.28', '119.23', '55.38', '53.27', '60', '70.45',
#        '40', '69', '57.89', '78.5', '69.64', '101.23', '20', '50', '75',
#        '83.33', '113.33', '33.33', '133.33', '61.11', '82.53', '78.94',
#        '167.34', '84', '153.84', '81.81', '120', '84.55', '72.34',
#        '114.81', '97.05', '84.37', '78.57', '78.35', '86.66', '150',
#        '76.47', '63.63', '110.16', '25', '92.02', '76.92', '107.14',
#        '100', '52.54', '73.86', '31.57', '9.09', '137.5', '79.27',
#        '68.81', '73.68', '76.13', '90.47', '7.14', '58.33', '136.36',
#        '102.32', '92.85', '85.4', '57.14', '79.1', '96.42', '121.87',
#        '18.18', '116.66', '95.34', '46.15', '71.05', '72.72', '29.41',
#        '112.35', '62.5', '113.79', '72', '97.08', '130', '106.25', '97.7',
#        '97.69', '138.09', '121.05', '41.66', '55', '63.79', '85.1',
#        '103.22', '124', '4.34', '109.09', '64.28', '14.28', '104',
# ...

# %%
sachin['Balls Faced'].unique()
# Out:
# array(['2', '39', '35', '26', '65', '107', '44', '10', '100', '19', '56',
#        '81', '5', '6', '32', '30', '9', '18', '63', '49', '75', '77', '4',
#        '24', '136', '47', '54', '68', '64', '112', '134', '15', '20',
#        '51', '11', '59', '138', '91', '84', '137', '12', '88', '8', '111',
#        '93', '38', '126', '14', '33', '43', '70', '7', '28', '67', '86',
#        '13', '76', '17', '89', '29', '25', '103', '50', '16', '131',
#        '130', '21', '40', '58', '141', '31', '150', '23', '3', '153',
#        '125', '27', '129', '57', '42', '60', '79', '45', '119', '66',
#        '69', '95', '22', '135', '48', '96', '113', '104', '41', '97',
#        '61', '46', '71', '73', '72', '36', '102', '120', '121', '133',
#        '52', '147', '101', '115'], dtype=object)

# %%
sachin['4s']=sachin['4s'].astype('int64')
sachin['6s']=sachin['6s'].astype('int64')
sachin['Pos']=sachin['Pos'].astype('int64')
sachin['Inns']=sachin['Inns'].astype('int64')
sachin['Year']=sachin['Year'].astype('int64')
sachin['SR']=sachin['SR'].astype('float64')
sachin['Balls Faced']=sachin['Balls Faced'].astype('int64')
# converting the columns to the appropiate data types

# %%
sachin.info()
# provides a summary of the DataFrame 'sachin', including the data types of each column and the number of non-null entries.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264 entries, 1 to 294
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Innings Number  264 non-null    int64
#  1   Runs            264 non-null    int64
#  2   Mins            264 non-null    int64
#  3   Balls Faced     264 non-null    int64
#  4   4s              264 non-null    int64
#  5   6s              264 non-null    int64
#  6   SR              264 non-null    float64
#  7   Pos             264 non-null    int64
#  8   Dismissal       264 non-null    object
#  9   Inns            264 non-null    int64
#  10  Opposition      264 non-null    object
#  11  Ground          264 non-null    object
#  12  Year            264 non-null    int64
# dtypes: float64(1), int64(9), object(3)
# memory usage: 28.9+ KB

# %%
sachin['Runs'].unique()
# Out:
# array([  0,  36,  19,  31,  57,  21,   4,  69,  11,  84,  39,  82,   1,
#          3,  24,   5,  34,   8,  52,  15,  63,  40,   6, 115,  62,  66,
#         54,  88, 105,  13,  30,   7,  65, 127,  70,  90, 137,  64,  28,
#         67, 114,  14,  45,  44,   9, 117,   2,  53,  27, 100,  33,  18,
#         17, 128,  29,  23,  22,  37, 120,  32, 186,  12,  26, 122,  93,
#         25, 146,  35, 139, 101,  38,  68,  87,  81,  89, 102,  86, 141,
#         74,  16,  47, 123,  42,  95,  10,  55,  60,  99,  71,  94,  43,
#         79,  72,  97,  91,  50,  20, 163, 138, 175,  96, 200, 111,  85],
#       dtype=int64)

# %%
sachin['Runs']=sachin['Runs'].astype('int')

# %%
sachin['Fifty']=((sachin['Runs']>=50) & (sachin['Runs']<100)).astype('int')
sachin['Hundred']=(sachin['Runs']>=100).astype('int')
# 'Fifty': It checks if the 'Runs' column is greater than or equal to 50 and less than 100 and converts the resulting boolean values to integers (1 for True, 0 for False).
# 'Hundred': It checks if the 'Runs' column is greater than or equal to 100 and converts the resulting boolean values to integers (1 for True, 0 for False).

# %%
sachin
# Out:
#      Innings Number  Runs  Mins  Balls Faced  4s  6s      SR  Pos Dismissal  \
# 1                 2     0     2            2   0   0    0.00    5    caught
# 2                 3    36    51           39   5   0   92.30    6    caught
# 3                 4    19    38           35   1   1   54.28    4    bowled
# 4                 5    31    31           26   3   0  119.23    6    bowled
# 14               15    36    79           65   3   0   55.38    4    caught
# ..              ...   ...   ...          ...  ..  ..     ...  ...       ...
# 290             291    18    21           14   2   0  128.57    2    caught
# 291             292     2     9            6   0   0   33.33    2    caught
# 292             293     3    21           12   0   0   25.00    2    caught
# 293             294    14    34           15   2   0   93.33    2   run out
# 294             295   114   205          147  12   1   77.55    2    caught
#
# ...

# %%
sachin[sachin['Hundred']==1]
# Out:
#      Innings Number  Runs  Mins  Balls Faced  4s  6s      SR  Pos  \
# 60               61   115   184          136   9   3   84.55    2
# 66               67   105   180          134  10   0   78.35    2
# 73               74   127   175          138  15   1   92.02    2
# 76               77   137   198          137   8   5  100.00    2
# 89               90   114   157          126  14   0   90.47    1
# 99              100   117   188          137  13   2   85.40    2
# 115             116   100   132           89   5   7  112.35    2
# 120             121   100   156          103  13   0   97.08    2
# 123             124   128   182          131   8   2   97.70    2
# 124             125   127   155          130  13   1   97.69    2
# 132             133   120   191          141  11   2   85.10    1
# 134             135   186   221          150  20   3  124.00    2
# 145             146   122   195          138  12   0   88.40    2
# ...

# %%
sachin[sachin['Fifty']==1]
# Out:
#      Innings Number  Runs  Mins  Balls Faced  4s  6s      SR  Pos Dismissal  \
# 15               16    57   111          107   3   0   53.27    4    caught
# 19               20    69   116          100   3   0   69.00    4    caught
# 21               22    84   122          107   6   0   78.50    4    caught
# 30               31    82   116           81   6   1  101.23    5   not out
# 49               50    52    83           63   3   0   82.53    5   run out
# 51               52    82    69           49  15   2  167.34    2    caught
# 52               53    63    91           75   9   0   84.00    2       lbw
# 54               55    63   125           77   7   1   81.81    2    caught
# 62               63    62    80           54  13   0  114.81    2    bowled
# 63               64    66   101           68   8   0   97.05    2    caught
# 64               65    54   130           64   5   0   84.37    2    caught
# ...

# %%
Opposition_vs_100 = pd.pivot_table(data=sachin,index='Opposition',columns='Hundred',values='Runs',aggfunc='count',fill_value=0)[1]
Opposition_vs_100
# creating a pivot table that shows the count of centuries (100 runs or more) scored against each opposition team.
# fill_value=0 sets the fill value for missing entries to 0.
# [1] is used to select only the column corresponding to centuries.
# Out:
# Opposition
# v Australia       5
# v Bangladesh      1
# v England         0
# v Ireland         0
# v Kenya           2
# v Netherlands     0
# v New Zealand     5
# v Pakistan        3
# v South Africa    5
# v Sri Lanka       4
# v U.A.E.          0
# v West Indies     2
# v Zimbabwe        2
# Name: 1, dtype: int64

# %%
Opposition_vs_50 = pd.pivot_table(data=sachin,index='Opposition',columns='Fifty',values='Runs',aggfunc='count',fill_value=0)[1]
Opposition_vs_50
# creating a pivot table that shows the count of fifties scored against each opposition team.
# fill_value=0 sets the fill value for missing entries to 0.
# [1] is used to select only the column corresponding to fifties.
# Out:
# Opposition
# v Australia       13
# v Bangladesh       1
# v England          8
# v Ireland          0
# v Kenya            0
# v Netherlands      0
# v New Zealand      5
# v Pakistan         4
# v South Africa     4
# v Sri Lanka       11
# v U.A.E.           1
# v West Indies      7
# v Zimbabwe         3
# Name: 1, dtype: int64

# %%
sachin['Dismissal'].unique()
# Out:
# array(['caught', 'bowled', 'run out', 'not out', 'lbw', 'stumped',
#        'retired notout'], dtype=object)

# %%
Dismissal_vs_opposition = pd.crosstab(index=sachin['Opposition'],columns=sachin['Dismissal'],margins=True,margins_name='Total')
Dismissal_vs_opposition
# createing a cross-table that shows the frequency of each type of dismissal against each opposition team.
# Out:
# Dismissal       bowled  caught  lbw  not out  retired notout  run out  \
# Opposition
# v Australia          7      32    4        1               0        6
# v Bangladesh         0       6    0        0               0        1
# v England            8      14    4        2               0        2
# v Ireland            1       0    1        0               0        0
# v Kenya              0       1    1        2               0        0
# v Netherlands        0       1    0        0               0        0
# v New Zealand        4      19    4        1               1        2
# v Pakistan           5      18    2        0               0        2
# v South Africa       6      20    2        1               0        0
# v Sri Lanka          5      18    6        4               0        3
# v U.A.E.             0       1    0        0               0        0
# v West Indies        5      11    1        3               0        1
# ...

# %%
Position_wise_runs = sachin.groupby('Pos')['Runs'].sum().sort_values(ascending=False)
Position_wise_runs
# grouping the data by the 'Pos' (Position) column, calculates the sum of 'Runs' for each position, and sorts the result in descending order.
# Out:
# Pos
# 2    8618
# 4     956
# 1     865
# 5     243
# 6      67
# 3      64
# Name: Runs, dtype: int32

# %%
Innings_wise_runs = sachin.groupby('Inns')['Runs'].sum().sort_values(ascending=False)
Innings_wise_runs
# grouping the data by the 'Inns' (Innings) column, calculates the sum of 'Runs' for each innings, and sorts the result in descending order.
# Out:
# Inns
# 1    5529
# 2    5284
# Name: Runs, dtype: int32

# %%
total_runs_by_opp = pd.crosstab(index=sachin['Opposition'],columns='Total Runs',values=sachin['Runs'],aggfunc='sum').sort_values(by='Total Runs',ascending=False)
total_runs_by_opp = total_runs_by_opp['Total Runs']
total_runs_by_opp
# createing a cross-tabulation that shows the total runs scored against each opposition team.
# Out:
# Opposition
# v Australia       2229
# v Sri Lanka       1673
# v New Zealand     1319
# v South Africa    1282
# v Pakistan        1020
# v England         1015
# v West Indies      865
# v Zimbabwe         677
# v Bangladesh       331
# v Kenya            270
# v U.A.E.            63
# v Ireland           42
# v Netherlands       27
# Name: Total Runs, dtype: int32

# %%
Ground_wise_runs = pd.pivot_table(data=sachin,index='Ground',values='Runs',aggfunc='sum').sort_values(by='Runs',ascending=False).head(20)
Ground_wise_runs
#  createing a pivot table that shows the total runs scored on each ground.
# Out:
#                     Runs
# Ground
# Colombo (RPS)        613
# Hyderabad (Deccan)   530
# Gwalior              525
# Nagpur               512
# Cuttack              465
# Mumbai               455
# Vadodara             442
# Bengaluru            414
# Kolkata              330
# Jaipur               318
# Kanpur               316
# Mohali               301
# Delhi                300
# Dhaka                279
# Sydney               261
# Rajkot               230
# Ahmedabad            213
# Christchurch         203
# Harare               192
# Brisbane             191

# %%
import matplotlib.pyplot as plt # For plotting
import seaborn as sb # For data Visualization

# %%
plt.hist(sachin['Runs'],bins=10)
plt.title('Distribution of Runs')
plt.xlabel('Runs')
plt.ylabel('Frequency')
plt.show()
# The histogram shows that the most common run score is between 25 and 50 runs. There are also a significant number of scores between 50 and 75 runs, and between 75 and 100 runs. Fewer scores are above 100 runs

# %%
Total_runs_yearly = pd.crosstab(index=sachin['Year'],columns='Total Runs',values=sachin['Runs'],aggfunc='sum').sort_values(by='Total Runs',ascending=False)
Total_runs_yearly= Total_runs_yearly['Total Runs']
Total_runs_yearly
# Total_runs_yearly shows the total runs scored in each year, with the years sorted in descending order based on the total runs.
# Out:
# Year
# 7     1161
# 96     902
# 94     865
# 9      849
# 98     702
# 0      656
# 4      587
# 97     579
# 1      552
# 3      501
# 99     428
# 2      416
# 5      412
# 6      404
# 11     393
# 8      320
# 92     238
# 10     200
# 93     160
# 95     155
# 12     133
# 91     114
# 90      86
# Name: Total Runs, dtype: int32

# %%
Total_runs_yearly.plot(kind='barh',color='green')
plt.title('Total Runs Per Year')
plt.xlabel('Total Runs')
plt.ylabel('Year')
plt.show()
# The horizontal bar graph shows that Sachin scored the highest runs by year in 2007.

# %%
sr = round(pd.crosstab(index=sachin['Opposition'],columns='Strike Rate',values=sachin['SR'],aggfunc='mean').sort_values(by='Strike Rate',ascending=False),2)
sr = sr['Strike Rate']
sr
# sr showing the average strike rate against different opposition teams.
# Out:
# Opposition
# v Netherlands     122.72
# v Ireland         100.59
# v Bangladesh       96.32
# v Kenya            83.13
# v U.A.E.           81.81
# v Sri Lanka        79.19
# v England          74.93
# v New Zealand      74.57
# v Australia        72.86
# v Zimbabwe         71.51
# v Pakistan         70.10
# v South Africa     66.83
# v West Indies      65.34
# Name: Strike Rate, dtype: float64

# %%
sr.plot(kind='barh')
plt.title('Opposition wise Average Strike Rate')
plt.xlabel('Strike Rate')
plt.ylabel('Opposition')
plt.show()
# Sachin has the highest average strike rate against Netherlands and least aganist West Indies.

# %%
plt.figure(figsize=(8,5))
sb.regplot(data=sachin,x='Runs',y='Balls Faced',scatter=True)
plt.title('Relation between Runs Vs Balls Faced')
plt.xlabel('Runs')
plt.ylabel('Balls Faced')
plt.show()
# regplot gives us a linear regression line
# the graph shows that there is a positive correlation between runs scored and balls faced in cricket.
# However, the relationship is non-linear, with batsmen scoring runs at a higher rate towards the end of an innings.
# There are a few possible explanations for the non-linear relationship between runs scored and balls faced. One possibility is that batsmen are more likely to take risks early in their innings in order to score quickly. Another possibility is that bowlers become more tired towards the end of an innings, which makes it easier for batsmen to score runs.

# %%
sachin[['Runs','Balls Faced']].corr()
# he correlation coefficient is approximately 0.95, which indicates a strong positive correlation between the number of runs scored and the number of balls faced. This suggests that as the number of runs increases, the number of balls faced also tends to increase, and vice versa.
# Out:
#                  Runs  Balls Faced
# Runs         1.000000     0.954084
# Balls Faced  0.954084     1.000000

# %%
plt.figure(figsize=(8,5))
sb.regplot(data=sachin,x='Mins',y='Runs',color='green')
plt.title('Relation between Runs scored by Mins')
plt.xlabel('Mins')
plt.ylabel('Runs')
plt.show()
plt.show()
# The graph shows a positive correlation between runs scored and minutes played. This means that the longer a batsman plays, the more runs they are likely to score. This is because batsmen have more time to score runs if they play for more minutes.

# %%
sachin_corr = sachin[['Runs','Balls Faced','4s','6s','SR']].corr()
sachin_corr
# Shows the correlation matrix for the variables 'Runs', 'Balls Faced', '4s', '6s', and 'SR'. This matrix shows the pairwise correlations between these variables.
# Out:
#                  Runs  Balls Faced        4s        6s        SR
# Runs         1.000000     0.954084  0.908745  0.589781  0.555575
# Balls Faced  0.954084     1.000000  0.834233  0.473788  0.406981
# 4s           0.908745     0.834233  1.000000  0.428331  0.608479
# 6s           0.589781     0.473788  0.428331  1.000000  0.361390
# SR           0.555575     0.406981  0.608479  0.361390  1.000000

# %%
plt.figure(figsize=(8,5))
sb.heatmap(sachin_corr,annot=True,fmt='.2f')
plt.title('Correlation between Runs, Balls Faced, 4s, 6s and SR')
plt.show()
# The correlation matrix shows that runs are strongly correlated with balls faced (0.95), 4s (0.91), and 6s (0.59). This means that batsmen who face more balls and hit more 4s and 6s are more likely to score more runs.
# SR is also strongly correlated with 4s (0.83) and 6s (0.61). This means that batsmen who hit more 4s and 6s are more likely to have a higher strike rate.
# The correlation matrix shows that runs, balls faced, 4s, 6s, and SR are all highly correlated.
# The correlation matrix can be used to help coaches and captains identify batsmen who are in good form and to develop strategies for batsmen to improve their performance.
